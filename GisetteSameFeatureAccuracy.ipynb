# %%
from scipy.io import loadmat
from scipy.sparse import issparse
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from Data import VFLDataset
from torch.utils.data import DataLoader
import VFL
import torch
import os
DIR = "Data"

# %%
file_name = 'gisette.mat'
mat = loadmat(os.path.join(DIR, file_name))
X = mat["X"]
y = mat["Y"]
if issparse(X):
    X = X.todense()
y = y.flatten()
print(file_name, X.shape, y.shape)
y[np.where(y == -1)] = 0
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
dataset = VFLDataset(data_source=(X, y), 
                    num_clients=2,
                    gini_portion=None,
                    insert_noise=False,
                    test_size=0.5)
train_loader = DataLoader(dataset.train(), batch_size=128, shuffle=True)
val_loader = DataLoader(dataset.valid(), batch_size=1000, shuffle=True)
test_loader = DataLoader(dataset.test(), batch_size=1000, shuffle=True)
input_dim_list = dataset.get_input_dim_list()
output_dim = np.unique(y).size
criterion = torch.nn.CrossEntropyLoss()
# Out:
# gisette.mat (7000, 5000) (7000,)
# Client 0: Feature Index 0-1666
# Client 1: Feature Index 1667-3333
# Server : Feature Index 3334-4999

# %%
models, top_model = VFL.make_binary_models(
                            input_dim_list=input_dim_list,
                            type='STG',
                            emb_dim=8,
                            output_dim=output_dim, hidden_dims=[8, 8],
                            activation='relu', lam=0.2)

gini_labels = dataset.gini_filter(0.5)
feat_idx_list = dataset.get_feature_index_list()
mus = VFL.initialize_mu(gini_labels, feat_idx_list)
mus = VFL.initialize_mu(gini_labels, feat_idx_list)
gini_models, gini_top_model = VFL.make_binary_models(
                            input_dim_list=input_dim_list,
                            type='STG',
                            emb_dim=8,
                            output_dim=output_dim, hidden_dims=[8, 8],
                            activation='relu', lam=0.2, mus=mus)
    
mus = VFL.initialize_mu(gini_labels, feat_idx_list)
dual_models, dual_top_model = VFL.make_binary_models(
                            input_dim_list=input_dim_list,
                            type='DualSTG',
                            emb_dim=8,
                            output_dim=output_dim, hidden_dims=[8, 8],
                            activation='relu', lam=0.2, mus=mus, top_lam=0.1)

# %%
results = []
for i, step in enumerate([10]*20):
    history = VFL.train(models, top_model, train_loader, val_loader, test_loader,
                epochs=step, noise_label=None, criterion=criterion, 
                verbose=False, save_mask_at=100000)
    
    num_feats = history.tail(1)['num_feats'].item()
    acc = history.tail(1)['test_acc'].item()
    print(f'STG:{num_feats}')
    print(f'STG Acc:{acc}')
    gini_history = VFL.train(
        gini_models, gini_top_model, train_loader, val_loader, test_loader,
        epochs=step, noise_label=None, criterion=criterion,
        verbose=False, save_mask_at=100000)
    gini_num_feats = gini_history.tail(1)['num_feats'].item()
    gini_acc = gini_history.tail(1)['test_acc'].item()
    print(f'GINI+STG: {gini_num_feats}')
    print(f'GINI+STG Acc: {gini_acc}')
    dual_history = VFL.train(
        dual_models, dual_top_model, train_loader, val_loader, test_loader,
        epochs=step, noise_label=None, criterion=criterion,
        verbose=False, save_mask_at=100000, freeze_top_till=5)
    saved_communication = dual_history['num_emb'].sum()
    pred_emb = dual_history.tail(1)['num_emb'].item()
    dual_acc = dual_history.tail(1)['test_acc'].item()
    dual_num_feats = dual_history.tail(1)['num_feats'].item()
    print(f'DualSTG: {dual_acc}')
    print(f'DualSTG: {saved_communication}')
    print(f'DualSTG: {dual_num_feats}')
    print("What's the Test accuracy if SFFS only have this much features?")
    percentage = num_feats/X.shape[1]
    sffs_labels = dataset.gini_filter(percentage)
    sffs_labels = sffs_labels.flatten()
    X_temp, y_temp = dataset.get_data()
    X_filtered = X_temp[:, np.nonzero(sffs_labels)].squeeze() 
    print(X_filtered.shape)
    sffs_dataset = VFLDataset(data_source=(X_filtered, y), 
                    num_clients=2,
                    gini_portion=None,
                    insert_noise=False,
                    test_size=0.5)
    sffs_train_loader = DataLoader(sffs_dataset.train(), batch_size=128, shuffle=True)
    sffs_val_loader = DataLoader(sffs_dataset.valid(), batch_size=1000, shuffle=True)
    sffs_test_loader = DataLoader(sffs_dataset.test(), batch_size=1000, shuffle=True)
    sffs_input_dim_list = sffs_dataset.get_input_dim_list()
    sffs_output_dim = np.unique(y).size
    sffs_models, sffs_top_model = VFL.make_binary_models(
                            input_dim_list=sffs_input_dim_list,
                            type='FNN',
                            emb_dim=8,
                            output_dim=sffs_output_dim, hidden_dims=[8, 8],
                            activation='relu')
    sffs_history = VFL.train(sffs_models, sffs_top_model, sffs_train_loader, 
                                sffs_val_loader, sffs_test_loader,
                                epochs=step, noise_label=None, criterion=criterion,
                                verbose=False, save_mask_at=100000)
    sffs_acc = sffs_history.tail(1)['test_acc'].item()
    print(f'SFFS Acc: {sffs_acc}')
    results.append([acc, num_feats, gini_acc, gini_num_feats, dual_num_feats,
        dual_acc, saved_communication, pred_emb, sffs_acc])
# Out:
# STG:3353
# STG Acc:0.97075
# GINI+STG: 2397
# GINI+STG Acc: 0.99675
# DualSTG: 0.9884999999999999
# DualSTG: 218
# DualSTG: 2354
# What's the Test accuracy if SFFS only have this much features?
# (7000, 3353)
# Client 0: Feature Index 0-1117
# Client 1: Feature Index 1118-2235
# Server : Feature Index 2236-3352
# SFFS Acc: 0.9475
# STG:2245
# STG Acc:0.997
# GINI+STG: 1878
# GINI+STG Acc: 0.996
# DualSTG: 0.9924999999999999
# DualSTG: 153
# DualSTG: 1919
# What's the Test accuracy if SFFS only have this much features?
# (7000, 2245)
# Client 0: Feature Index 0-748
# Client 1: Feature Index 749-1496
# Server : Feature Index 1497-2244
# SFFS Acc: 0.7172499999999999
# STG:1694
# STG Acc:0.9965
# GINI+STG: 1471
# GINI+STG Acc: 0.9924999999999999
# DualSTG: 0.99225
# DualSTG: 85
# DualSTG: 1574
# What's the Test accuracy if SFFS only have this much features?
# (7000, 1694)
# Client 0: Feature Index 0-564
# Client 1: Feature Index 565-1129
# Server : Feature Index 1130-1693
# SFFS Acc: 0.863
# STG:1243
# STG Acc:0.9984999999999999
# GINI+STG: 1185
# GINI+STG Acc: 0.998
# DualSTG: 0.99475
# DualSTG: 50
# DualSTG: 1293
# What's the Test accuracy if SFFS only have this much features?
# (7000, 1243)
# Client 0: Feature Index 0-414
# Client 1: Feature Index 415-828
# Server : Feature Index 829-1242
# SFFS Acc: 0.8017500000000002
# STG:934
# STG Acc:0.99675
# GINI+STG: 976
# GINI+STG Acc: 0.99725
# DualSTG: 0.996
# DualSTG: 35
# DualSTG: 1047
# What's the Test accuracy if SFFS only have this much features?
# (7000, 934)
# Client 0: Feature Index 0-311
# Client 1: Feature Index 312-622
# Server : Feature Index 623-933
# SFFS Acc: 0.78125
# STG:741
# STG Acc:0.99875
# GINI+STG: 827
# GINI+STG Acc: 0.9975
# DualSTG: 0.97525
# DualSTG: 20
# DualSTG: 897
# What's the Test accuracy if SFFS only have this much features?
# (7000, 741)
# Client 0: Feature Index 0-246
# Client 1: Feature Index 247-493
# Server : Feature Index 494-740
# SFFS Acc: 0.79725
# STG:605
# STG Acc:0.99725
# GINI+STG: 728
# GINI+STG Acc: 0.99675
# DualSTG: 0.9975
# DualSTG: 20
# DualSTG: 775
# What's the Test accuracy if SFFS only have this much features?
# (7000, 605)
# Client 0: Feature Index 0-201
# Client 1: Feature Index 202-403
# Server : Feature Index 404-604
# SFFS Acc: 0.7402499999999999
# STG:548
# STG Acc:0.99825
# GINI+STG: 634
# GINI+STG Acc: 0.9955
# DualSTG: 0.9964999999999999
# DualSTG: 20
# DualSTG: 658
# What's the Test accuracy if SFFS only have this much features?
# (7000, 548)
# Client 0: Feature Index 0-182
# Client 1: Feature Index 183-365
# Server : Feature Index 366-547
# SFFS Acc: 0.7557499999999999
# STG:501
# STG Acc:0.998
# GINI+STG: 548
# GINI+STG Acc: 0.99575
# DualSTG: 0.997
# DualSTG: 24
# DualSTG: 547
# What's the Test accuracy if SFFS only have this much features?
# (7000, 501)
# Client 0: Feature Index 0-166
# Client 1: Feature Index 167-333
# Server : Feature Index 334-500
# SFFS Acc: 0.83675
# STG:478
# STG Acc:0.99725
# GINI+STG: 488
# GINI+STG Acc: 0.9942500000000001
# DualSTG: 0.9957499999999999
# DualSTG: 26
# DualSTG: 477
# What's the Test accuracy if SFFS only have this much features?
# (7000, 478)
# Client 0: Feature Index 0-159
# Client 1: Feature Index 160-318
# Server : Feature Index 319-477
# SFFS Acc: 0.79525
# STG:438
# STG Acc:0.9982500000000001
# GINI+STG: 456
# GINI+STG Acc: 0.9974999999999999
# DualSTG: 0.9977499999999999
# DualSTG: 20
# DualSTG: 455
# What's the Test accuracy if SFFS only have this much features?
# (7000, 438)
# Client 0: Feature Index 0-145
# Client 1: Feature Index 146-291
# Server : Feature Index 292-437
# SFFS Acc: 0.8022500000000001
# STG:412
# STG Acc:0.9984999999999999
# GINI+STG: 429
# GINI+STG Acc: 0.9972500000000001
# DualSTG: 0.9955
# DualSTG: 20
# DualSTG: 372
# What's the Test accuracy if SFFS only have this much features?
# (7000, 412)
# Client 0: Feature Index 0-137
# Client 1: Feature Index 138-274
# Server : Feature Index 275-411
# SFFS Acc: 0.77675
# STG:374
# STG Acc:0.998
# GINI+STG: 382
# GINI+STG Acc: 0.9922500000000001
# DualSTG: 0.9964999999999999
# DualSTG: 20
# DualSTG: 320
# What's the Test accuracy if SFFS only have this much features?
# (7000, 374)
# Client 0: Feature Index 0-124
# Client 1: Feature Index 125-249
# Server : Feature Index 250-373
# SFFS Acc: 0.7957500000000001
# STG:339
# STG Acc:0.9984999999999999
# GINI+STG: 366
# GINI+STG Acc: 0.9964999999999999
# DualSTG: 0.998
# DualSTG: 20
# DualSTG: 294
# What's the Test accuracy if SFFS only have this much features?
# (7000, 339)
# Client 0: Feature Index 0-112
# Client 1: Feature Index 113-225
# Server : Feature Index 226-338
# SFFS Acc: 0.74075
# STG:327
# STG Acc:0.9975
# GINI+STG: 341
# GINI+STG Acc: 0.996
# DualSTG: 0.9984999999999999
# DualSTG: 20
# DualSTG: 280
# What's the Test accuracy if SFFS only have this much features?
# (7000, 327)
# Client 0: Feature Index 0-108
# Client 1: Feature Index 109-217
# Server : Feature Index 218-326
# SFFS Acc: 0.75525
# STG:302
# STG Acc:0.996
# GINI+STG: 319
# GINI+STG Acc: 0.9984999999999999
# DualSTG: 0.9907499999999999
# DualSTG: 20
# DualSTG: 269
# What's the Test accuracy if SFFS only have this much features?
# (7000, 302)
# Client 0: Feature Index 0-100
# Client 1: Feature Index 101-201
# Server : Feature Index 202-301
# SFFS Acc: 0.7057499999999999
# STG:285
# STG Acc:0.9964999999999999
# GINI+STG: 310
# GINI+STG Acc: 0.98725
# DualSTG: 0.998
# DualSTG: 20
# DualSTG: 251
# What's the Test accuracy if SFFS only have this much features?
# (7000, 285)
# Client 0: Feature Index 0-94
# Client 1: Feature Index 95-189
# Server : Feature Index 190-284
# SFFS Acc: 0.663
# STG:272
# STG Acc:0.99825
# GINI+STG: 302
# GINI+STG Acc: 0.9965
# DualSTG: 0.9990000000000001
# DualSTG: 20
# DualSTG: 248
# What's the Test accuracy if SFFS only have this much features?
# (7000, 272)
# Client 0: Feature Index 0-90
# Client 1: Feature Index 91-181
# Server : Feature Index 182-271
# SFFS Acc: 0.69675
# STG:262
# STG Acc:0.997
# GINI+STG: 290
# GINI+STG Acc: 0.9962500000000001
# DualSTG: 0.998
# DualSTG: 20
# DualSTG: 244
# What's the Test accuracy if SFFS only have this much features?
# (7000, 262)
# Client 0: Feature Index 0-87
# Client 1: Feature Index 88-174
# Server : Feature Index 175-261
# SFFS Acc: 0.6769999999999999
# STG:244
# STG Acc:0.999
# GINI+STG: 276
# GINI+STG Acc: 0.998
# DualSTG: 0.99825
# DualSTG: 20
# DualSTG: 233
# What's the Test accuracy if SFFS only have this much features?
# (7000, 244)
# Client 0: Feature Index 0-81
# Client 1: Feature Index 82-162
# Server : Feature Index 163-243
# SFFS Acc: 0.64525

# %%
import pandas as pd
results = pd.DataFrame(results, columns=['STG_acc', 'STG_feats', 
'GINI_acc', 'GINI+STG_feats', 
'DualSTG_feats', 'DualSTG_acc', 'Saved_communication', 'pred_emb',
'SFFS_acc'])
results['Epochs'] = np.arange(0, 200, 10)
results['STG_communication'] = 240
results.to_csv('results/CSVResults/gisette_results.csv')

# %%
import matplotlib.pyplot as plt
x = results['STG_feats']
#plt.plot(results['STG_feats'], results['STG_acc'], label='STG', )
plt.plot(results['STG_feats'], results['SFFS_acc'], label='SFFS', marker='^')
# plt.plot(results['STG_feats'], results['DualSTG_acc'], label='DualSTG')
plt.plot(results['STG_feats'], results['GINI_acc'], label='STG+GINI', marker='o')
plt.xlim(max(x), min(x))
plt.legend()
plt.xlabel('Number of features')
plt.ylabel('Test Accuracy')
plt.title('BASEHOCK Dataset')
plt.show()

# %%
fig, axd = plt.subplot_mosaic([['upper left', 'right'],
                               ['lower left', 'right']],
                              figsize=(10, 6), constrained_layout=True)
axd['upper left'].plot(np.arange(0, 200, 10), results['STG_acc'], label='STG', marker='o')
axd['upper left'].plot(np.arange(0, 200, 10), results['GINI_acc'], label='STG+GINI', marker='^')
axd['upper left'].plot(np.arange(0, 200, 10), results['DualSTG_acc'], label='DualSTG', marker='s')
axd['upper left'].legend()
axd['upper left'].set_xlabel('Number of Epochs')
axd['upper left'].set_ylabel('Test Accuracy')
axd['upper left'].set_title('Test Accuracy vs Number of Epochs')

axd['lower left'].plot(np.arange(0, 200, 10), results['STG_feats'], label='STG', marker='o')
axd['lower left'].plot(np.arange(0, 200, 10), results['GINI+STG_feats'], label='STG+GINI', marker='^')
axd['lower left'].plot(np.arange(0, 200, 10), results['DualSTG_feats'], label='DualSTG', marker='s')
axd['lower left'].set_xlabel('Number of Epochs')
axd['lower left'].set_ylabel('Number of Features')
axd['lower left'].set_title('# Selected Features vs Number of Epochs')
axd['lower left'].legend()


group_names = ['STG', 'STG+GINI', 'DualSTG']
values = [1, 1, results.tail(1)['pred_emb'].item()/24]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
axd['right'].bar(group_names, values, align='center', color=colors)
axd['right'].set_xlabel('Model')
axd['right'].set_ylabel('Ratio')
axd['right'].set_title('Predicition Communication Cost Ratio')
fig.suptitle('Arcene Dataset')
plt.show()
